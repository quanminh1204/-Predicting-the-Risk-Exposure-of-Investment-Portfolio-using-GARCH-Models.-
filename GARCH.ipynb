# %%
import numpy as np
import pandas as pd
import arch
from arch import arch_model
from riskfolio import VaR_Hist
from riskfolio import CVaR_Hist
import seaborn as sns

# %%
ret = pd.read_excel(r'return.xlsx')
ret.set_index('Date', inplace= True)

# %%
#returns
#returns['Date'] = returns['Date'].astype('datetime64')
#returns.set_index('Date', inplace= True)

# %%
ret
# Out:
#                  vhm       vcb       fpt       agg       agr       asp  \
# Date
# 2020-12-24 -0.012665 -0.002054 -0.008734 -0.045068 -0.043616 -0.034412
# 2020-12-25  0.014951  0.003079  0.010471  0.036556  0.047067  0.032790
# 2020-12-28  0.001141  0.004090  0.005196 -0.015505  0.000000 -0.016252
# 2020-12-29  0.029215  0.012170  0.012017 -0.008716 -0.017387  0.006529
# 2020-12-30 -0.001108 -0.013191 -0.008569 -0.010564 -0.018893  0.001621
# ...              ...       ...       ...       ...       ...       ...
# 2023-03-27 -0.012320  0.022223  0.006341  0.000000  0.042966  0.005479
# 2023-03-28 -0.008299  0.008753  0.001263 -0.001771 -0.007034 -0.001823
# 2023-03-29  0.000000  0.005432 -0.002528 -0.003552  0.022107  0.000000
# 2023-03-30  0.036814 -0.003256 -0.001267 -0.001781  0.018245 -0.012856
# 2023-03-31  0.033567 -0.006543  0.002532  0.007105  0.059228  0.034518
#
#                  msb       nvl       ree
# Date
# 2020-12-24  0.017492 -0.015040 -0.016632
# 2020-12-25  0.067059  0.007550  0.006271
# 2020-12-28  0.013429  0.008979 -0.007321
# 2020-12-29  0.013243  0.011854  0.001049
# 2020-12-30 -0.005280 -0.016333  0.012501
# ...              ...       ...       ...
# 2023-03-27  0.000000  0.065064  0.007380
# 2023-03-28  0.004107 -0.007905  0.000000
# 2023-03-29  0.000000 -0.003976 -0.011834
# 2023-03-30  0.024293  0.023623 -0.002981
# 2023-03-31  0.007968 -0.011742  0.008915
#
# [564 rows x 9 columns]

# %%
ret.describe()
# Out:
#               vhm         vcb         fpt         agg         agr         asp  \
# count  564.000000  564.000000  564.000000  564.000000  564.000000  564.000000
# mean    -0.000397    0.000339    0.001210    0.000385    0.000170   -0.000117
# std      0.021049    0.018322    0.019052    0.018938    0.034247    0.029956
# min     -0.072425   -0.072372   -0.072400   -0.097896   -0.077782   -0.112869
# 25%     -0.011177   -0.010132   -0.006542   -0.006951   -0.018229   -0.013979
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.009593    0.009792    0.009695    0.006419    0.018302    0.013178
# max      0.067467    0.060625    0.067628    0.096159    0.067661    0.067663
#
#               msb         nvl         ree
# count  564.000000  564.000000  564.000000
# mean     0.000399   -0.001125    0.000857
# std      0.023783    0.028062    0.025143
# min     -0.072404   -0.072546   -0.072539
# 25%     -0.009394   -0.009975   -0.012028
# 50%      0.000000    0.000000    0.001247
# 75%      0.010809    0.009039    0.011904
# max      0.067659    0.207897    0.067471

# %%
train_data = ret.iloc[:500,:]
test_data = ret.iloc[500:,:]

# %%
coeffs = []
cond_vol = []
std_resids = []
models = []
infor_aic = []
infor_bic = []
pred = []

# %%
for asset in train_data.columns:
    model = arch_model(train_data[asset], mean='Constant', vol='GARCH', p=1, o=0, q=1).fit(update_freq=0, disp='off')
    predict = model.forecast(horizon= len(test_data))
    coeffs.append(model.params)
    cond_vol.append(model.conditional_volatility)
    std_resids.append(model.resid / model.conditional_volatility)
    models.append(model)
    infor_aic.append(model.aic)
    infor_bic.append(model.bic)
    pred.append(predict.variance.values[-1])
# Out:
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004252. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003387. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003949. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003929. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.001238. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0009762. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0005935. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0007122. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0006834. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(

# %%
models
# Out:
# [                     Constant Mean - GARCH Model Results
#  ==============================================================================
#  Dep. Variable:                    vhm   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                      GARCH   Log-Likelihood:                1262.60
#  Distribution:                  Normal   AIC:                          -2517.20
#  Method:            Maximum Likelihood   BIC:                          -2500.34
#                                          No. Observations:                  500
#  Date:                Mon, Apr 24 2023   Df Residuals:                      499
#  Time:                        00:40:05   Df Model:                            1
#                                    Mean Model
#  ==============================================================================
#                    coef    std err          t      P>|t|       95.0% Conf. Int.
#  ------------------------------------------------------------------------------
#  mu         -7.3135e-04  8.564e-04     -0.854      0.393 [-2.410e-03,9.471e-04]
#                                Volatility Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  omega      4.2519e-05  7.720e-06      5.508  3.639e-08 [2.739e-05,5.765e-05]
#  alpha[1]       0.2000  5.866e-02      3.409  6.510e-04   [8.502e-02,  0.315]
#  beta[1]        0.7000  6.723e-02     10.412  2.176e-25     [  0.568,  0.832]
#  ============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x2538a422f80,
#                       Constant Mean - GARCH Model Results
#  ==============================================================================
#  Dep. Variable:                    vcb   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                      GARCH   Log-Likelihood:                1301.31
#  Distribution:                  Normal   AIC:                          -2594.62
#  Method:            Maximum Likelihood   BIC:                          -2577.76
#                                          No. Observations:                  500
#  Date:                Mon, Apr 24 2023   Df Residuals:                      499
#  Time:                        00:40:05   Df Model:                            1
#                                    Mean Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  mu         2.6393e-04  7.304e-04      0.361      0.718 [-1.168e-03,1.695e-03]
#                                Volatility Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  omega      7.5363e-05  1.370e-05      5.503  3.740e-08 [4.852e-05,1.022e-04]
#  alpha[1]       0.1501  5.349e-02      2.806  5.012e-03   [4.527e-02,  0.255]
#  beta[1]        0.6314  5.883e-02     10.732  7.232e-27     [  0.516,  0.747]
#  ============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x2538a40add0,
#                       Constant Mean - GARCH Model Results
#  ==============================================================================
#  Dep. Variable:                    fpt   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                      GARCH   Log-Likelihood:                1287.81
#  Distribution:                  Normal   AIC:                          -2567.62
#  Method:            Maximum Likelihood   BIC:                          -2550.77
#                                          No. Observations:                  500
#  Date:                Mon, Apr 24 2023   Df Residuals:                      499
#  Time:                        00:40:05   Df Model:                            1
#                                    Mean Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  mu         7.2862e-04  8.183e-04      0.890      0.373 [-8.752e-04,2.332e-03]
#                                Volatility Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  omega      7.8994e-06  8.790e-11  8.986e+04      0.000 [7.899e-06,7.900e-06]
#  alpha[1]       0.1000  3.157e-02      3.167  1.538e-03   [3.812e-02,  0.162]
#  beta[1]        0.8800  2.815e-02     31.260 1.609e-214     [  0.825,  0.935]
#  ============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x2538a409960,
#                       Constant Mean - GARCH Model Results
#  ==============================================================================
#  Dep. Variable:                    agg   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                      GARCH   Log-Likelihood:                1271.66
#  Distribution:                  Normal   AIC:                          -2535.33
#  Method:            Maximum Likelihood   BIC:                          -2518.47
#                                          No. Observations:                  500
#  Date:                Mon, Apr 24 2023   Df Residuals:                      499
#  Time:                        00:40:05   Df Model:                            1
#                                   Mean Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  mu         7.5535e-04  1.150e-06    656.567      0.000 [7.531e-04,7.576e-04]
#                                Volatility Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  omega      7.8571e-06  4.075e-11  1.928e+05      0.000 [7.857e-06,7.857e-06]
#  alpha[1]       0.0500  2.873e-02      1.740  8.178e-02  [-6.307e-03,  0.106]
#  beta[1]        0.9300  2.666e-02     34.890 1.057e-266     [  0.878,  0.982]
#  ============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x2538a409360,
#                       Constant Mean - GARCH Model Results
#  ==============================================================================
#  Dep. Variable:                    agr   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                      GARCH   Log-Likelihood:                980.004
#  Distribution:                  Normal   AIC:                          -1952.01
#  Method:            Maximum Likelihood   BIC:                          -1935.15
#                                          No. Observations:                  500
#  Date:                Mon, Apr 24 2023   Df Residuals:                      499
#  Time:                        00:40:05   Df Model:                            1
#                                    Mean Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  mu         6.1778e-04  1.398e-03      0.442      0.659 [-2.123e-03,3.359e-03]
#                                Volatility Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  omega      1.2378e-04  5.935e-05      2.086  3.701e-02 [7.460e-06,2.401e-04]
#  alpha[1]       0.1000  2.617e-02      3.821  1.330e-04   [4.870e-02,  0.151]
#  beta[1]        0.8000  5.834e-02     13.712  8.594e-43     [  0.686,  0.914]
#  ============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x253883fb010,
#                       Constant Mean - GARCH Model Results
#  ==============================================================================
#  Dep. Variable:                    asp   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                      GARCH   Log-Likelihood:                1044.42
#  Distribution:                  Normal   AIC:                          -2080.85
#  Method:            Maximum Likelihood   BIC:                          -2063.99
#                                          No. Observations:                  500
#  Date:                Mon, Apr 24 2023   Df Residuals:                      499
#  Time:                        00:40:05   Df Model:                            1
#                                    Mean Model
#  ==============================================================================
#                    coef    std err          t      P>|t|       95.0% Conf. Int.
#  ------------------------------------------------------------------------------
#  mu         -2.8831e-04  1.266e-03     -0.228      0.820 [-2.769e-03,2.193e-03]
#                                 Volatility Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  omega      2.8182e-04  1.616e-04      1.744  8.108e-02 [-3.482e-05,5.984e-04]
#  alpha[1]       0.2061  7.273e-02      2.834  4.603e-03    [6.354e-02,  0.349]
#  beta[1]        0.5030      0.225      2.236  2.538e-02    [6.202e-02,  0.944]
#  =============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x253883f8fa0,
#                       Constant Mean - GARCH Model Results
#  ==============================================================================
#  Dep. Variable:                    msb   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                      GARCH   Log-Likelihood:                1164.22
#  Distribution:                  Normal   AIC:                          -2320.44
#  Method:            Maximum Likelihood   BIC:                          -2303.58
#                                          No. Observations:                  500
#  Date:                Mon, Apr 24 2023   Df Residuals:                      499
#  Time:                        00:40:05   Df Model:                            1
#                                    Mean Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  mu         8.9830e-04  1.000e-03      0.898      0.369 [-1.062e-03,2.858e-03]
#                                Volatility Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  omega      5.7076e-05  2.334e-05      2.445  1.448e-02 [1.133e-05,1.028e-04]
#  alpha[1]       0.1155  3.662e-02      3.153  1.615e-03   [4.369e-02,  0.187]
#  beta[1]        0.7922  5.423e-02     14.609  2.447e-48     [  0.686,  0.898]
#  ============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x253883fb820,
#                       Constant Mean - GARCH Model Results
#  ==============================================================================
#  Dep. Variable:                    nvl   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                      GARCH   Log-Likelihood:                1190.81
#  Distribution:                  Normal   AIC:                          -2373.62
#  Method:            Maximum Likelihood   BIC:                          -2356.77
#                                          No. Observations:                  500
#  Date:                Mon, Apr 24 2023   Df Residuals:                      499
#  Time:                        00:40:06   Df Model:                            1
#                                    Mean Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  mu         1.5573e-03  5.825e-03      0.267      0.789 [-9.859e-03,1.297e-02]
#                                 Volatility Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  omega      7.1222e-05  4.923e-04      0.145      0.885 [-8.936e-04,1.036e-03]
#  alpha[1]       0.2000      0.165      1.210      0.226      [ -0.124,  0.524]
#  beta[1]        0.7000      1.145      0.611      0.541      [ -1.545,  2.945]
#  =============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x2538a40b1f0,
#                       Constant Mean - GARCH Model Results
#  ==============================================================================
#  Dep. Variable:                    ree   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                      GARCH   Log-Likelihood:                1148.08
#  Distribution:                  Normal   AIC:                          -2288.17
#  Method:            Maximum Likelihood   BIC:                          -2271.31
#                                          No. Observations:                  500
#  Date:                Mon, Apr 24 2023   Df Residuals:                      499
#  Time:                        00:40:06   Df Model:                            1
#                                    Mean Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  mu         1.0942e-03  9.478e-04      1.154      0.248 [-7.635e-04,2.952e-03]
#                                Volatility Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  omega      6.8342e-05  2.420e-05      2.824  4.739e-03 [2.091e-05,1.158e-04]
#  alpha[1]       0.1000  2.350e-02      4.255  2.092e-05   [5.394e-02,  0.146]
#  beta[1]        0.8000  4.855e-02     16.477  5.402e-61     [  0.705,  0.895]
#  ============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x253883eac50]

# %%
coeffs_df = pd.DataFrame(coeffs).transpose().set_axis(train_data.columns, axis='columns', inplace=False)
cond_vol_df = pd.DataFrame(cond_vol).transpose().set_axis(train_data.columns, axis='columns', inplace=False)
std_resids_df = pd.DataFrame(std_resids).transpose().set_axis(train_data.columns, axis='columns', inplace=False)
pred_df = pd.DataFrame(np.sqrt(pred)).transpose().set_axis(train_data.columns, axis='columns', inplace=False)
pred_df.set_index(test_data.index, inplace= True)
MSE = np.mean((pred_df - test_data)**2)
infor_df = pd.DataFrame({'AIC': infor_aic, 'BIC': infor_bic, 'MSE': MSE}).set_index(train_data.columns, inplace=False)
# Out:
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
coeffs_df
# Out:
#                vhm       vcb       fpt       agg       agr       asp  \
# mu       -0.000731  0.000264  0.000729  0.000755  0.000618 -0.000288
# omega     0.000043  0.000075  0.000008  0.000008  0.000124  0.000282
# alpha[1]  0.199990  0.150105  0.100000  0.050000  0.100000  0.206074
# beta[1]   0.700015  0.631383  0.880000  0.930000  0.799998  0.503034
#
#                msb       nvl       ree
# mu        0.000898  0.001557  0.001094
# omega     0.000057  0.000071  0.000068
# alpha[1]  0.115457  0.200000  0.100000
# beta[1]   0.792196  0.700000  0.799999

# %%
infor_df
# Out:
#              AIC          BIC       MSE
# vhm -2517.202737 -2500.344304  0.000974
# vcb -2594.615337 -2577.756904  0.000562
# fpt -2567.624584 -2550.766151  0.000394
# agg -2535.325048 -2518.466616  0.000535
# agr -1952.008805 -1935.150373  0.001655
# asp -2080.846893 -2063.988461  0.001147
# msb -2320.438668 -2303.580235  0.000934
# nvl -2373.624527 -2356.766095  0.002383
# ree -2288.168569 -2271.310136  0.000942

# %% [markdown]
# ## Giá trị VaR và CVaR dự báo

# %%
VaR_95 = []
CVaR_95 = []
VaR_99 = []
CVaR_99 = []

for i in pred_df.columns:
    cal_VaR_95 = VaR_Hist(pred_df[i], alpha= 0.05)
    cal_CVaR_95 = CVaR_Hist(pred_df[i], alpha= 0.05)
    cal_VaR_99 = VaR_Hist(pred_df[i], alpha= 0.01)
    cal_CVaR_99 = CVaR_Hist(pred_df[i], alpha= 0.01)
    VaR_95.append(cal_VaR_95)
    CVaR_95.append(cal_CVaR_95)
    VaR_99.append(cal_VaR_99)
    CVaR_99.append(cal_VaR_99)

VaR_df = pd.DataFrame({'VaR 95%': VaR_95,
                       'VaR 99%': VaR_99,
                       'CVaR 95%': CVaR_95,
                       'CVaR 99%': CVaR_99}).set_axis(train_data.columns, inplace=False)
VaR_df
# Out:
#       VaR 95%   VaR 99%  CVaR 95%  CVaR 99%
# vhm -0.020103 -0.019908 -0.019985 -0.019908
# vcb -0.016851 -0.014738 -0.015657 -0.014738
# fpt -0.014933 -0.014569 -0.014708 -0.014569
# agg -0.020046 -0.020033 -0.020037 -0.020033
# agr -0.034601 -0.034382 -0.034469 -0.034382
# asp -0.029495 -0.026298 -0.027745 -0.026298
# msb -0.022690 -0.021910 -0.022220 -0.021910
# nvl -0.026716 -0.026708 -0.026711 -0.026708
# ree -0.023384 -0.022272 -0.022717 -0.022272

# %%
# Tính trọng số đều cho các mã
weights = np.array([1/9, 1/9, 1/9, 1/9, 1/9, 1/9, 1/9, 1/9, 1/9])

# Tính VaR và CVaR của danh mục đầu tư
portfolio_VaR_95 = np.sum(weights * VaR_95)
portfolio_VaR_99 = np.sum(weights * VaR_99)
portfolio_CVaR_95 = np.sum(weights * CVaR_95)
portfolio_CVaR_99 = np.sum(weights * CVaR_99)

risk = pd.DataFrame(data= [portfolio_VaR_95, portfolio_VaR_99, portfolio_CVaR_95, portfolio_CVaR_99],
                    index= ['VaR 95%', 'VaR 99%', 'CVaR 95%', 'CVaR 99%'], columns= ['Portfolio'])
risk
# Out:
#           Portfolio
# VaR 95%   -0.023202
# VaR 99%   -0.022313
# CVaR 95%  -0.022694
# CVaR 99%  -0.022313

# %%
#from scipy.optimize import minimize

# %%
#def objective_function(weights, VaR_99, CVaR_99):
   # portfolio_VaR = np.sum(weights * VaR_99)
   # portfolio_CVaR = np.sum(weights * CVaR_99)
   # return portfolio_CVaR - portfolio_VaR

# %%
# Thêm ràng buộc và hạn chế để đảm bảo rằng tổng trọng số bằng 1 và các trọng số không âm
#def constraint1(weights):
    #return np.sum(weights) - 1

# %%
#constraints = [{'type': 'eq', 'fun': constraint1}]
#bounds = [(0, 1)] * len(VaR)

# %%
#optimized = minimize(objective_function,
                   #  x0 = [1.0/len(train_data.columns)]*len(train_data.columns),
                   #  args=(VaR_95, CVaR_95),
                   #  method='SLSQP',
                   #  bounds=bounds,
                   #  constraints=constraints)

# %%
#new_weight = pd.DataFrame(optimized.x, columns= ['weight']).transpose().set_axis(train_data.columns, axis='columns', inplace=False)
#new_weight.applymap('{:.2%}'.format)
